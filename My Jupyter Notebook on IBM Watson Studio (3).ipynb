# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Helder Mateus**
# Credit Risk Analyst

# %% [markdown]
# _I am interested in data science because data is the most powerful asset any company can have to in order to develop, improve business strategies based on data and statistics in order to increase revenue and profitability and to better reach the desired outcomes._

# %% [markdown]
# ## The code that I have written displays "Hello World"

# %%
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# 1. item one
# 1. item two
# 1. item three
#
# * item one
# * item two
# * item three
#
# ~strikethrough text~
